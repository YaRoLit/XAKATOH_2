# %% [markdown]
# # Импорты (нужно установить эти библиотеки)

# %%
import numpy as np
import pandas as pd
import requests
import json
import csv

# %% [markdown]
# # Тестовый фрейм для одиночного запроса

# %%
test_request = {
    'BirthDate':            '1980-03-20',
    'education':            'Высшее - специалист',
    'employment_status':    'Собственное дело',
    'Value':                '10 и более лет',
    'JobStartDate':         '2012-10-01',
    'Position':             'Просто умный человек',
    'MonthProfit':          150000.0,
    'MonthExpense':         '22500.0', 
    'Gender':               'мач0',
    'Family_status':        'Никогда в браке не состоял(а)',
    'ChildCount':           '0',
    'SNILS':                '0',
    'Merch_code':           '15',
    'Loan_amount':          '48000.0',
    'Loan_term':            '6',
    'Goods_category':       'Medical_services'
}

# %% [markdown]
# # Образец одиночного Get и Post запроса

# %%
# Get запрос к начальной странице, возвращает статус запроса.
r = requests.get('http://127.0.0.1:5000/')
print(r.status_code, r.reason)
# Out:
# 200 OK

# %%
# Одиночный Post запрос к странице /AskOraqul/ с передачей фрейма данных.
# Возвращает статус получения запроса и вероятность одобрения
# банками A...E заявки на получения кредита по указанным параметрам.
json_data = json.dumps(test_request).encode('utf8')
r = requests.post(
    # Запрос на сервер, который поднят на нашей виртуальной машине в Яндекс Облаке
    'http://158.160.135.101:5000/AskOraqul/', data=json_data)
    # Запрос на локальный сервер (в случае развертывания на локальной машине)
    #'http://127.0.0.1:5000/AskOraqul/', data=json_data)
print(r.status_code, r.reason)
resp = r.content.decode()[1:-1].split(',')
BankA_decision = round(float(resp[0]), 2)
BankB_decision = round(float(resp[1]), 2)
BankC_decision = round(float(resp[2]), 2)
BankD_decision = round(float(resp[3]), 2)
BankE_decision = round(float(resp[4]), 2)
print(BankA_decision, BankB_decision, BankC_decision, BankD_decision, BankE_decision)
# Out:
# 200 OK
# 0.76 0.74 0.76 0.78 0.73

# %% [markdown]
# # Post запросы в цикле с перебором строк из загружаемого датафрейма или *.csv файла

# %% [markdown]
# **Запросы отсылаются по аналогии с примерами, приведенными выше, но в качестве исходных данных выступают *.csv файл или pd.DataFrame, содержащие параметры клиентов, в отношении которых необходимо получить вероятность одобрения кредита. Запрос возвращает кортеж из вероятностей одобрения банками A..E заявок по каждому клиенту.**

# %% [markdown]
# ### Пример передачи в виде post запросов содержимого файла *.csv напрямую

# %%
with open('./data/model_val.csv') as f:
    next(f)  # Skip the header
    reader = csv.reader(f, skipinitialspace=True, delimiter=';')
    for row in reader:
        test_request = {} 
        test_request['BirthDate']           = row[1]
        test_request['education']           = row[2]
        test_request['employment_status']   = row[3]
        test_request['Value']               = row[4]
        test_request['JobStartDate']        = row[5]
        test_request['Position']            = row[6]
        test_request['MonthProfit']         = row[7]
        test_request['MonthExpense']        = row[8]
        test_request['Gender']              = row[9]
        test_request['Family_status']       = row[10]
        test_request['ChildCount']          = row[11]
        test_request['SNILS']               = row[12]
        test_request['Merch_code']          = row[18]
        test_request['Loan_amount']         = row[19]
        test_request['Loan_term']           = row[20]
        test_request['Goods_category']      = row[21]
        json_data = json.dumps(test_request).encode('utf8')
        r = requests.post(
            # Запрос на сервер, который поднят на нашей виртуальной машине в Яндекс Облаке
            'http://158.160.135.101:5000/AskOraqul/', data=json_data)
            # Запрос на локальный сервер (в случае развертывания на локальной машине)
            #'http://127.0.0.1:5000/AskOraqul/', data=json_data)
        print(r.status_code, r.reason)
        resp = r.content.decode()[1:-1].split(',')
        BankA_decision = round(float(resp[0]), 2)
        BankB_decision = round(float(resp[1]), 2)
        BankC_decision = round(float(resp[2]), 2)
        BankD_decision = round(float(resp[3]), 2)
        BankE_decision = round(float(resp[4]), 2)
        print(BankA_decision, BankB_decision, BankC_decision, BankD_decision, BankE_decision)
# Out:
# 200 OK
# 0.75 0.73 0.74 0.76 0.77
# 200 OK
# 0.72 0.73 0.75 0.76 0.75
# 200 OK
# 0.76 0.73 0.76 0.72 0.74
# 200 OK
# 0.81 0.79 0.78 0.79 0.75
# 200 OK
# 0.73 0.75 0.72 0.7 0.73
# 200 OK
# 0.74 0.78 0.79 0.75 0.71
# 200 OK
# 0.74 0.72 0.75 0.79 0.71
# 200 OK
# 0.78 0.7 0.72 0.77 0.75
# 200 OK
# 0.73 0.74 0.73 0.7 0.76
# 200 OK
# 0.79 0.75 0.7 0.72 0.75
# 200 OK
# 0.77 0.7 0.69 0.75 0.78
# 200 OK
# 0.79 0.74 0.75 0.75 0.73
# 200 OK
# 0.75 0.79 0.73 0.75 0.74
# 200 OK
# 0.75 0.74 0.7 0.74 0.73
# 200 OK
# 0.77 0.72 0.75 0.74 0.76
# 200 OK
# 0.75 0.76 0.76 0.71 0.75
# 200 OK
# 0.72 0.76 0.75 0.75 0.76
# 200 OK
# 0.74 0.8 0.75 0.68 0.74
# 200 OK
# 0.65 0.77 0.72 0.77 0.77
# 200 OK
# 0.74 0.77 0.77 0.77 0.76
# 200 OK
# 0.75 0.73 0.75 0.77 0.74
# 200 OK
# 0.77 0.71 0.74 0.74 0.72
# 200 OK
# 0.76 0.76 0.73 0.7 0.75
# 200 OK
# 0.77 0.74 0.78 0.68 0.73
# 200 OK
# 0.76 0.75 0.75 0.78 0.75
# 200 OK
# 0.78 0.68 0.65 0.71 0.74
# 200 OK
# 0.78 0.74 0.71 0.75 0.77
# 200 OK
# 0.77 0.76 0.71 0.79 0.75
# 200 OK
# 0.71 0.76 0.75 0.76 0.73
# 200 OK
# 0.77 0.74 0.78 0.77 0.76
# 200 OK
# 0.69 0.77 0.74 0.78 0.79
# 200 OK
# 0.75 0.76 0.76 0.75 0.73
# 200 OK
# 0.76 0.77 0.73 0.76 0.75
# 200 OK
# 0.74 0.76 0.77 0.72 0.74
# 200 OK
# 0.79 0.71 0.78 0.77 0.81
# 200 OK
# 0.74 0.77 0.78 0.77 0.72
# 200 OK
# 0.73 0.7 0.77 0.78 0.74
# 200 OK
# 0.73 0.75 0.68 0.75 0.75
# 200 OK
# 0.73 0.78 0.71 0.78 0.72
# 200 OK
# 0.75 0.76 0.72 0.76 0.74
# 200 OK
# 0.79 0.73 0.75 0.76 0.73
# 200 OK
# 0.78 0.73 0.74 0.71 0.76
# 200 OK
# 0.76 0.74 0.75 0.79 0.74
# 200 OK
# 0.73 0.73 0.76 0.75 0.72
# 200 OK
# 0.75 0.75 0.71 0.72 0.72
# 200 OK
# 0.74 0.75 0.75 0.76 0.71
# 200 OK
# 0.72 0.74 0.72 0.76 0.72
# 200 OK
# 0.78 0.76 0.78 0.76 0.75
# 200 OK
# 0.67 0.76 0.73 0.77 0.66
# 200 OK
# 0.74 0.73 0.71 0.7 0.73
# 200 OK
# 0.79 0.74 0.78 0.78 0.75
# 200 OK
# 0.83 0.78 0.76 0.8 0.67
# 200 OK
# 0.74 0.76 0.71 0.75 0.68
# 200 OK
# 0.75 0.74 0.76 0.77 0.76
# 200 OK
# 0.77 0.77 0.74 0.71 0.73
# 200 OK
# 0.74 0.79 0.77 0.78 0.75
# 200 OK
# 0.76 0.71 0.69 0.72 0.72
# 200 OK
# 0.69 0.75 0.75 0.77 0.72
# 200 OK
# 0.77 0.72 0.73 0.72 0.73
# 200 OK
# 0.69 0.77 0.8 0.7 0.79
# 200 OK
# 0.79 0.73 0.76 0.8 0.73
# 200 OK
# 0.77 0.75 0.75 0.73 0.76
# 200 OK
# 0.73 0.77 0.75 0.74 0.75
# 200 OK
# 0.75 0.79 0.73 0.79 0.69
# 200 OK
# 0.78 0.77 0.78 0.72 0.71
# 200 OK
# 0.73 0.77 0.71 0.75 0.76
# 200 OK
# 0.77 0.71 0.73 0.73 0.75
# 200 OK
# 0.74 0.72 0.76 0.78 0.77
# 200 OK
# 0.71 0.75 0.71 0.76 0.76
# 200 OK
# 0.79 0.65 0.72 0.74 0.76
# 200 OK
# 0.74 0.75 0.75 0.77 0.76
# 200 OK
# 0.73 0.73 0.72 0.72 0.75
# 200 OK
# 0.76 0.75 0.78 0.76 0.74
# 200 OK
# 0.74 0.78 0.77 0.67 0.69
# 200 OK
# 0.79 0.74 0.74 0.71 0.77
# 200 OK
# 0.76 0.72 0.68 0.75 0.74
# 200 OK
# 0.74 0.75 0.78 0.77 0.78
# 200 OK
# 0.82 0.79 0.8 0.78 0.75
# 200 OK
# 0.8 0.72 0.7 0.82 0.74
# 200 OK
# 0.75 0.74 0.76 0.75 0.73
# 200 OK
# 0.77 0.74 0.78 0.74 0.77
# 200 OK
# 0.74 0.77 0.73 0.73 0.7
# 200 OK
# 0.75 0.7 0.75 0.73 0.74
# 200 OK
# 0.76 0.77 0.74 0.75 0.79
# 200 OK
# 0.75 0.72 0.75 0.74 0.74
# 200 OK
# 0.75 0.7 0.74 0.78 0.77
# 200 OK
# 0.77 0.74 0.75 0.71 0.77
# 200 OK
# 0.75 0.76 0.78 0.67 0.79
# 200 OK
# 0.73 0.75 0.76 0.75 0.77
# 200 OK
# 0.75 0.76 0.77 0.74 0.76
# 200 OK
# 0.72 0.77 0.78 0.74 0.72
# 200 OK
# 0.71 0.74 0.73 0.8 0.75
# 200 OK
# 0.75 0.76 0.75 0.72 0.77
# 200 OK
# 0.78 0.76 0.75 0.71 0.75
# 200 OK
# 0.75 0.78 0.74 0.74 0.74
# 200 OK
# 0.75 0.73 0.74 0.72 0.75
# 200 OK
# 0.79 0.68 0.73 0.76 0.76
# 200 OK
# 0.75 0.73 0.77 0.73 0.76
# 200 OK
# 0.76 0.76 0.74 0.79 0.74
# 200 OK
# 0.75 0.73 0.76 0.75 0.75
# 200 OK
# 0.76 0.74 0.76 0.69 0.74
# 200 OK
# 0.73 0.79 0.72 0.67 0.78
# 200 OK
# 0.75 0.74 0.73 0.73 0.74
# 200 OK
# 0.79 0.74 0.75 0.66 0.77
# 200 OK
# 0.76 0.73 0.75 0.74 0.73
# 200 OK
# 0.8 0.6 0.66 0.75 0.69
# 200 OK
# 0.75 0.8 0.75 0.76 0.77
# 200 OK
# 0.77 0.78 0.62 0.84 0.76
# 200 OK
# 0.75 0.78 0.77 0.65 0.74
# 200 OK
# 0.78 0.68 0.73 0.8 0.67
# 200 OK
# 0.75 0.73 0.76 0.73 0.77
# 200 OK
# 0.76 0.72 0.74 0.79 0.76
# 200 OK
# 0.75 0.75 0.73 0.76 0.76
# 200 OK
# 0.76 0.78 0.73 0.73 0.74
# 200 OK
# 0.75 0.72 0.77 0.7 0.75
# 200 OK
# 0.75 0.74 0.76 0.76 0.71
# 200 OK
# 0.75 0.76 0.77 0.74 0.75
# 200 OK
# 0.75 0.74 0.74 0.74 0.76
# 200 OK
# 0.75 0.69 0.75 0.78 0.75
# 200 OK
# 0.76 0.76 0.79 0.74 0.76
# 200 OK
# 0.78 0.74 0.73 0.72 0.76
# 200 OK
# 0.74 0.74 0.76 0.74 0.76
# 200 OK
# 0.75 0.78 0.77 0.73 0.78
# 200 OK
# 0.76 0.72 0.72 0.75 0.77
# 200 OK
# 0.79 0.76 0.72 0.67 0.81
# 200 OK
# 0.78 0.68 0.71 0.79 0.76
# 200 OK
# 0.69 0.7 0.76 0.71 0.76
# 200 OK
# 0.78 0.71 0.75 0.76 0.77
# 200 OK
# 0.74 0.75 0.8 0.74 0.8
# 200 OK
# 0.74 0.73 0.8 0.81 0.77
# 200 OK
# 0.72 0.71 0.74 0.79 0.73
# 200 OK
# 0.75 0.78 0.7 0.74 0.74
# 200 OK
# 0.76 0.79 0.75 0.74 0.75
# 200 OK
# 0.74 0.78 0.78 0.73 0.75
# 200 OK
# 0.74 0.79 0.74 0.71 0.75
# 200 OK
# 0.64 0.78 0.7 0.78 0.71
# 200 OK
# 0.76 0.76 0.74 0.76 0.74
# 200 OK
# 0.8 0.63 0.8 0.79 0.75
# 200 OK
# 0.72 0.77 0.79 0.73 0.71
# 200 OK
# 0.75 0.75 0.68 0.82 0.72
# 200 OK
# 0.62 0.71 0.7 0.7 0.68
# 200 OK
# 0.78 0.71 0.73 0.7 0.76
# 200 OK
# 0.76 0.74 0.75 0.72 0.73
# 200 OK
# 0.75 0.76 0.73 0.71 0.72
# 200 OK
# 0.74 0.75 0.77 0.75 0.76
# 200 OK
# 0.78 0.73 0.69 0.73 0.72
# 200 OK
# 0.77 0.77 0.75 0.78 0.75
# 200 OK
# 0.77 0.71 0.77 0.75 0.76
# 200 OK
# 0.76 0.74 0.75 0.76 0.74
# 200 OK
# 0.74 0.76 0.78 0.73 0.74
# 200 OK
# 0.79 0.68 0.72 0.72 0.73
# 200 OK
# 0.77 0.75 0.72 0.77 0.77
# 200 OK
# 0.75 0.73 0.81 0.8 0.79
# 200 OK
# 0.73 0.78 0.75 0.77 0.75
# 200 OK
# 0.77 0.75 0.76 0.72 0.74
# 200 OK
# 0.73 0.67 0.77 0.78 0.76
# 200 OK
# 0.73 0.73 0.77 0.74 0.72
# 200 OK
# 0.74 0.74 0.74 0.76 0.74
# 200 OK
# 0.78 0.75 0.8 0.75 0.75
# 200 OK
# 0.67 0.69 0.72 0.71 0.69
# 200 OK
# 0.74 0.71 0.77 0.76 0.76
# 200 OK
# 0.79 0.76 0.74 0.75 0.77
# 200 OK
# 0.75 0.74 0.75 0.75 0.68
# 200 OK
# 0.71 0.72 0.76 0.75 0.74
# 200 OK
# 0.78 0.73 0.74 0.74 0.74
# 200 OK
# 0.73 0.76 0.77 0.73 0.74
# 200 OK
# 0.77 0.75 0.8 0.79 0.73
# 200 OK
# 0.77 0.8 0.75 0.81 0.72
# 200 OK
# 0.75 0.75 0.76 0.76 0.77
# 200 OK
# 0.63 0.8 0.73 0.76 0.78
# 200 OK
# 0.74 0.74 0.76 0.79 0.72
# 200 OK
# 0.74 0.8 0.82 0.74 0.75
# 200 OK
# 0.73 0.72 0.75 0.77 0.77
# 200 OK
# 0.78 0.75 0.73 0.68 0.75
# 200 OK
# 0.75 0.8 0.67 0.65 0.74
# 200 OK
# 0.77 0.74 0.77 0.74 0.72
# 200 OK
# 0.76 0.73 0.8 0.74 0.68
# 200 OK
# 0.74 0.79 0.78 0.69 0.67
# 200 OK
# 0.76 0.74 0.75 0.75 0.77
# 200 OK
# 0.74 0.75 0.76 0.76 0.75
# 200 OK
# 0.71 0.76 0.74 0.75 0.74
# 200 OK
# 0.71 0.73 0.75 0.79 0.78
# 200 OK
# 0.74 0.75 0.75 0.74 0.73
# 200 OK
# 0.77 0.72 0.65 0.72 0.71
# 200 OK
# 0.76 0.76 0.76 0.74 0.75
# 200 OK
# 0.76 0.75 0.75 0.79 0.77
# 200 OK
# 0.73 0.76 0.8 0.7 0.76
# 200 OK
# 0.78 0.74 0.74 0.74 0.71
# 200 OK
# 0.79 0.63 0.69 0.74 0.7
# 200 OK
# 0.71 0.73 0.74 0.78 0.78
# 200 OK
# 0.73 0.72 0.7 0.7 0.73
# 200 OK
# 0.76 0.69 0.75 0.77 0.76
# 200 OK
# 0.77 0.64 0.75 0.72 0.73
# 200 OK
# 0.74 0.77 0.77 0.76 0.72
# 200 OK
# 0.73 0.72 0.8 0.74 0.75
# 200 OK
# 0.74 0.76 0.77 0.74 0.72
# 200 OK
# 0.75 0.74 0.74 0.72 0.72
# 200 OK
# 0.77 0.72 0.73 0.73 0.69
# 200 OK
# 0.77 0.69 0.73 0.78 0.73
# 200 OK
# 0.75 0.8 0.77 0.72 0.69
# 200 OK
# 0.75 0.74 0.77 0.73 0.72
# 200 OK
# 0.76 0.73 0.74 0.73 0.73
# 200 OK
# 0.81 0.8 0.82 0.78 0.83
# 200 OK
# 0.74 0.78 0.77 0.75 0.75
# 200 OK
# 0.74 0.78 0.74 0.73 0.76
# 200 OK
# 0.76 0.71 0.73 0.76 0.73
# 200 OK
# 0.82 0.73 0.75 0.76 0.66
# 200 OK
# 0.75 0.74 0.76 0.75 0.73
# 200 OK
# 0.8 0.68 0.7 0.72 0.72
# 200 OK
# 0.78 0.69 0.72 0.68 0.78
# 200 OK
# 0.74 0.72 0.7 0.76 0.78
# 200 OK
# 0.71 0.8 0.8 0.75 0.75
# 200 OK
# 0.8 0.79 0.81 0.72 0.78
# 200 OK
# 0.76 0.75 0.75 0.77 0.78
# 200 OK
# 0.75 0.74 0.76 0.76 0.74
# 200 OK
# 0.73 0.7 0.74 0.69 0.79
# 200 OK
# 0.75 0.75 0.79 0.72 0.74
# 200 OK
# 0.77 0.79 0.74 0.74 0.73
# 200 OK
# 0.75 0.73 0.76 0.75 0.78
# 200 OK
# 0.75 0.75 0.74 0.78 0.73
# 200 OK
# 0.79 0.68 0.72 0.76 0.74
# 200 OK
# 0.75 0.76 0.79 0.73 0.73
# 200 OK
# 0.78 0.72 0.74 0.73 0.76
# 200 OK
# 0.73 0.73 0.75 0.73 0.74
# 200 OK
# 0.75 0.71 0.67 0.75 0.75
# 200 OK
# 0.75 0.75 0.75 0.71 0.79
# 200 OK
# 0.74 0.75 0.72 0.7 0.72
# 200 OK
# 0.75 0.75 0.8 0.78 0.78
# 200 OK
# 0.77 0.73 0.74 0.72 0.79
# 200 OK
# 0.73 0.64 0.74 0.69 0.81
# 200 OK
# 0.76 0.76 0.75 0.71 0.74
# 200 OK
# 0.77 0.73 0.78 0.76 0.75
# 200 OK
# 0.76 0.77 0.76 0.68 0.79
# 200 OK
# 0.75 0.75 0.72 0.75 0.81
# 200 OK
# 0.75 0.78 0.74 0.78 0.73
# 200 OK
# 0.69 0.73 0.8 0.69 0.74
# 200 OK
# 0.74 0.72 0.78 0.75 0.74
# 200 OK
# 0.77 0.72 0.76 0.77 0.74
# 200 OK
# 0.76 0.73 0.72 0.77 0.74
# 200 OK
# 0.75 0.75 0.78 0.72 0.78
# 200 OK
# 0.78 0.72 0.75 0.77 0.73
# 200 OK
# 0.77 0.75 0.78 0.74 0.71
# 200 OK
# 0.79 0.76 0.73 0.77 0.75
# 200 OK
# 0.73 0.78 0.73 0.72 0.74
# 200 OK
# 0.68 0.75 0.72 0.78 0.77
# 200 OK
# 0.78 0.76 0.77 0.67 0.77
# 200 OK
# 0.74 0.79 0.75 0.78 0.77
# 200 OK
# 0.8 0.66 0.8 0.78 0.75
# 200 OK
# 0.73 0.77 0.7 0.8 0.7
# 200 OK
# 0.74 0.73 0.78 0.7 0.68
# 200 OK
# 0.76 0.71 0.7 0.73 0.76
# 200 OK
# 0.77 0.76 0.75 0.74 0.76
# 200 OK
# 0.75 0.71 0.76 0.77 0.75
# 200 OK
# 0.74 0.76 0.76 0.76 0.78
# 200 OK
# 0.79 0.77 0.76 0.75 0.66
# 200 OK
# 0.74 0.76 0.78 0.77 0.75
# 200 OK
# 0.75 0.69 0.75 0.76 0.57
# 200 OK
# 0.77 0.75 0.75 0.77 0.76
# 200 OK
# 0.78 0.74 0.71 0.72 0.77
# 0.73 0.77 0.73 0.73 0.74
# 200 OK
# 0.81 0.78 0.75 0.67 0.76
# 200 OK
# 0.77 0.77 0.78 0.76 0.79
# 200 OK
# 0.72 0.72 0.74 0.78 0.74
# 200 OK
# 0.72 0.77 0.77 0.8 0.76
# 200 OK
# 0.75 0.76 0.81 0.67 0.75
# 200 OK
# 0.77 0.76 0.76 0.76 0.74
# 200 OK
# 0.77 0.74 0.66 0.75 0.7
# 200 OK
# 0.71 0.8 0.8 0.72 0.76
# 200 OK
# 0.75 0.74 0.76 0.72 0.76
# 200 OK
# 0.82 0.68 0.73 0.72 0.58
# 200 OK
# 0.74 0.73 0.67 0.74 0.74
# 200 OK
# 0.72 0.7 0.67 0.78 0.67
# 200 OK
# 0.71 0.74 0.65 0.71 0.74
# 200 OK
# 0.75 0.78 0.78 0.78 0.79
# 200 OK
# 0.71 0.78 0.74 0.74 0.73
# 200 OK
# 0.79 0.67 0.76 0.74 0.73
# 200 OK
# 0.74 0.74 0.76 0.72 0.74
# 200 OK
# 0.76 0.73 0.76 0.75 0.74
# 200 OK
# 0.76 0.74 0.78 0.77 0.78
# 200 OK
# 0.7 0.73 0.77 0.72 0.74
# 200 OK
# 0.78 0.77 0.73 0.74 0.72
# 200 OK
# 0.73 0.77 0.77 0.72 0.76
# 200 OK
# 0.74 0.76 0.77 0.73 0.76
# 200 OK
# 0.73 0.75 0.74 0.7 0.78
# 200 OK
# 0.65 0.73 0.76 0.75 0.74
# 200 OK
# 0.72 0.76 0.74 0.72 0.73
# 200 OK
# 0.76 0.77 0.66 0.8 0.77
# 200 OK
# 0.71 0.73 0.7 0.8 0.67
# 200 OK
# 0.76 0.77 0.8 0.76 0.78
# 200 OK
# 0.75 0.75 0.76 0.77 0.73
# 200 OK
# 0.76 0.76 0.71 0.76 0.75
# 200 OK
# 0.72 0.72 0.75 0.75 0.75
# 200 OK
# 0.74 0.75 0.76 0.74 0.77
# 200 OK
# 0.82 0.74 0.8 0.69 0.8
# 200 OK
# 0.75 0.8 0.78 0.75 0.75
# 200 OK
# 0.76 0.75 0.75 0.73 0.75
# 200 OK
# 0.79 0.61 0.83 0.71 0.71
# 200 OK
# 0.76 0.72 0.75 0.75 0.76
# 200 OK
# 0.77 0.7 0.74 0.77 0.73
# 200 OK
# 0.75 0.79 0.77 0.68 0.75
# 200 OK
# 0.8 0.78 0.74 0.74 0.76
# 200 OK
# 0.81 0.74 0.78 0.75 0.64
# 200 OK
# 0.75 0.73 0.74 0.75 0.75
# 200 OK
# 0.6 0.77 0.67 0.77 0.77
# 200 OK
# 0.74 0.75 0.78 0.73 0.75
# 200 OK
# 0.76 0.76 0.76 0.75 0.74
# 200 OK
# 0.76 0.75 0.76 0.75 0.77
# 200 OK
# 0.75 0.77 0.78 0.75 0.72
# 200 OK
# 0.75 0.75 0.72 0.76 0.75
# 200 OK
# 0.74 0.79 0.71 0.75 0.74
# 200 OK
# 0.75 0.73 0.74 0.77 0.75
# 200 OK
# 0.78 0.77 0.74 0.68 0.77
# 200 OK
# 0.83 0.75 0.8 0.82 0.73
# 200 OK
# 0.78 0.71 0.73 0.73 0.74
# 200 OK
# 0.77 0.78 0.77 0.71 0.78
# 200 OK
# 0.83 0.63 0.75 0.79 0.78
# 200 OK
# 0.77 0.76 0.74 0.81 0.75
# 200 OK
# 0.78 0.65 0.71 0.73 0.73
# 200 OK
# 0.74 0.76 0.77 0.72 0.78
# 200 OK
# 0.67 0.67 0.71 0.82 0.72
# 200 OK
# 0.77 0.77 0.67 0.74 0.74
# 200 OK
# 0.81 0.76 0.76 0.8 0.69
# 200 OK
# 0.73 0.74 0.74 0.78 0.75
# 200 OK
# 0.77 0.74 0.75 0.77 0.75
# 200 OK
# 0.76 0.77 0.77 0.68 0.76
# 200 OK
# 0.76 0.76 0.8 0.74 0.72
# 200 OK
# 0.73 0.74 0.77 0.73 0.73
# 200 OK
# 0.76 0.71 0.76 0.78 0.72
# 200 OK
# 0.74 0.75 0.76 0.77 0.78
# 200 OK
# 0.76 0.75 0.75 0.76 0.73
# 200 OK
# 0.8 0.79 0.73 0.76 0.64
# 200 OK
# 0.75 0.75 0.77 0.78 0.75
# 200 OK
# 0.72 0.72 0.74 0.69 0.73
# 200 OK
# 0.69 0.74 0.74 0.74 0.74
# 200 OK
# 0.71 0.74 0.72 0.77 0.75
# 200 OK
# 0.74 0.74 0.78 0.79 0.75
# 200 OK
# 0.7 0.7 0.78 0.72 0.74
# 200 OK
# 0.76 0.74 0.78 0.72 0.75
# 200 OK
# 0.78 0.69 0.68 0.72 0.73
# 200 OK
# 0.81 0.78 0.77 0.8 0.74
# 200 OK
# 0.69 0.78 0.76 0.73 0.75
# 200 OK
# 0.79 0.75 0.7 0.72 0.74
# 200 OK
# 0.74 0.74 0.77 0.78 0.76
# 200 OK
# 0.78 0.78 0.8 0.71 0.73
# 200 OK
# 0.67 0.74 0.72 0.74 0.7
# 200 OK
# 0.75 0.73 0.75 0.75 0.76
# 200 OK
# 0.78 0.74 0.75 0.74 0.72
# 200 OK
# 0.79 0.72 0.63 0.74 0.66
# 200 OK
# 0.74 0.76 0.73 0.72 0.75
# 200 OK
# 0.74 0.74 0.8 0.77 0.75
# 200 OK
# 0.73 0.75 0.77 0.73 0.76
# 200 OK
# 0.74 0.72 0.76 0.76 0.75
# 200 OK
# 0.76 0.73 0.75 0.75 0.74
# 200 OK
# 0.74 0.74 0.75 0.77 0.74
# 200 OK
# 0.82 0.67 0.72 0.71 0.72
# 200 OK
# 0.77 0.76 0.72 0.73 0.73
# 200 OK
# 0.78 0.73 0.82 0.75 0.73
# 200 OK
# 0.65 0.78 0.74 0.77 0.79
# 200 OK
# 0.8 0.66 0.78 0.76 0.74
# 200 OK
# 0.76 0.75 0.77 0.74 0.73
# 200 OK
# 0.78 0.74 0.72 0.77 0.75
# 200 OK
# 0.74 0.77 0.75 0.8 0.77
# 200 OK
# 0.78 0.74 0.8 0.8 0.79
# 200 OK
# 0.75 0.78 0.74 0.78 0.74
# 200 OK
# 0.76 0.8 0.67 0.7 0.73
# 200 OK
# 0.77 0.75 0.78 0.75 0.78
# 200 OK
# 0.84 0.75 0.78 0.84 0.76
# 200 OK
# 0.82 0.68 0.67 0.72 0.72
# 200 OK
# 0.69 0.71 0.76 0.71 0.69
# 200 OK
# 0.77 0.72 0.8 0.75 0.78
# 200 OK
# 0.7 0.8 0.78 0.71 0.75
# 200 OK
# 0.61 0.71 0.67 0.73 0.55
# 200 OK
# 0.78 0.67 0.74 0.73 0.79
# 200 OK
# 0.82 0.72 0.73 0.71 0.78
# 200 OK
# 0.77 0.71 0.76 0.76 0.7
# 200 OK
# 0.81 0.78 0.79 0.69 0.71
# 200 OK
# 0.78 0.69 0.72 0.74 0.77
# 200 OK
# 0.76 0.74 0.74 0.75 0.74
# 200 OK
# 0.75 0.74 0.76 0.76 0.78
# 200 OK
# 0.76 0.78 0.75 0.74 0.76
# 200 OK
# 0.76 0.72 0.75 0.74 0.74
# 200 OK
# 0.75 0.78 0.69 0.66 0.76
# 200 OK
# 0.8 0.69 0.76 0.75 0.74
# 200 OK
# 0.79 0.78 0.78 0.74 0.75
# 200 OK
# 0.79 0.74 0.71 0.72 0.74
# 200 OK
# 0.78 0.69 0.73 0.76 0.72
# 200 OK
# 0.77 0.68 0.71 0.76 0.61
# 200 OK
# 0.73 0.75 0.78 0.7 0.72
# 200 OK
# 0.74 0.75 0.8 0.75 0.74
# 200 OK
# 0.69 0.77 0.76 0.69 0.78
# 200 OK
# 0.82 0.79 0.82 0.45 0.75
# 200 OK
# 0.74 0.73 0.78 0.71 0.75
# 200 OK
# 0.73 0.73 0.76 0.77 0.76
# 200 OK
# 0.78 0.75 0.69 0.74 0.71
# 200 OK
# 0.75 0.75 0.75 0.76 0.74
# 200 OK
# 0.76 0.73 0.8 0.75 0.7
# 200 OK
# 0.75 0.72 0.77 0.76 0.77
# 200 OK
# 0.78 0.79 0.75 0.71 0.74
# 200 OK
# 0.73 0.75 0.74 0.73 0.73
# 200 OK
# 0.76 0.73 0.74 0.71 0.79
# 200 OK
# 0.73 0.77 0.77 0.74 0.77
# 200 OK
# 0.71 0.75 0.77 0.74 0.73
# 200 OK
# 0.75 0.76 0.79 0.74 0.74
# 200 OK
# 0.75 0.75 0.73 0.77 0.76
# 200 OK
# 0.78 0.69 0.7 0.75 0.75
# 200 OK
# 0.76 0.8 0.75 0.75 0.76
# 200 OK
# 0.75 0.75 0.74 0.77 0.76
# 200 OK
# 0.71 0.77 0.71 0.77 0.76
# 200 OK
# 0.66 0.76 0.67 0.77 0.77
# 200 OK
# 0.77 0.76 0.73 0.76 0.73
# 200 OK
# 0.73 0.77 0.8 0.73 0.77
# 200 OK
# 0.75 0.78 0.76 0.75 0.73
# 200 OK
# 0.81 0.78 0.77 0.8 0.74
# 200 OK
# 0.74 0.69 0.78 0.7 0.73
# 200 OK
# 0.77 0.76 0.69 0.82 0.71
# 200 OK
# 0.76 0.8 0.76 0.74 0.6
# 200 OK
# 0.73 0.74 0.71 0.72 0.75
# 200 OK
# 0.73 0.8 0.74 0.73 0.71
# 200 OK
# 0.74 0.74 0.74 0.74 0.72
# 200 OK
# 0.74 0.75 0.64 0.7 0.73
# 200 OK
# 0.76 0.74 0.73 0.77 0.74
# 200 OK
# 0.71 0.72 0.76 0.74 0.73
# 200 OK
# 0.74 0.77 0.76 0.72 0.74
# 200 OK
# 0.7 0.73 0.79 0.72 0.76
# 200 OK
# 0.75 0.77 0.7 0.73 0.76
# 200 OK
# 0.76 0.75 0.72 0.79 0.75
# 200 OK
# 0.77 0.66 0.73 0.75 0.72
# 200 OK
# 0.77 0.71 0.8 0.78 0.77
# 200 OK
# 0.77 0.64 0.77 0.72 0.79
# 200 OK
# 0.71 0.75 0.75 0.71 0.75
# 200 OK
# 0.73 0.76 0.7 0.72 0.74
# 200 OK
# 0.78 0.71 0.74 0.74 0.71
# 200 OK
# 0.78 0.7 0.72 0.75 0.74
# 200 OK
# 0.72 0.71 0.75 0.73 0.76
# 200 OK
# 0.75 0.77 0.79 0.78 0.75
# 200 OK
# 0.73 0.77 0.77 0.68 0.71
# 200 OK
# 0.77 0.76 0.73 0.73 0.72
# 200 OK
# 0.75 0.74 0.78 0.73 0.75
# 200 OK
# 0.74 0.75 0.77 0.71 0.73
# 200 OK
# 0.77 0.75 0.74 0.74 0.77
# 200 OK
# 0.73 0.7 0.67 0.78 0.57
# 200 OK
# 0.75 0.77 0.71 0.75 0.76
# 200 OK
# 0.79 0.73 0.71 0.74 0.72
# 200 OK
# 0.76 0.74 0.75 0.74 0.77
# 200 OK
# 0.77 0.71 0.76 0.75 0.7
# 200 OK
# 0.7 0.72 0.62 0.78 0.7
# 200 OK
# 0.71 0.76 0.77 0.72 0.75
# 200 OK
# 0.72 0.75 0.77 0.73 0.71
# 200 OK
# 0.79 0.62 0.74 0.81 0.58
# 200 OK
# 0.76 0.75 0.73 0.71 0.79
# 200 OK
# 0.72 0.74 0.77 0.8 0.75
# 200 OK
# 0.79 0.72 0.79 0.69 0.78
# 200 OK
# 0.77 0.74 0.78 0.75 0.66
# 200 OK
# 0.72 0.76 0.76 0.72 0.75
# 200 OK
# 0.8 0.76 0.78 0.8 0.73
# 200 OK
# 0.77 0.76 0.75 0.77 0.74
# 200 OK
# 0.76 0.73 0.76 0.77 0.75
# 200 OK
# 0.68 0.7 0.7 0.7 0.79
# 200 OK
# 0.72 0.75 0.77 0.71 0.73
# 200 OK
# 0.81 0.71 0.71 0.76 0.76
# 200 OK
# 0.81 0.68 0.66 0.73 0.64
# 200 OK
# 0.74 0.76 0.75 0.76 0.76
# 200 OK
# 0.76 0.76 0.76 0.76 0.75
# 200 OK
# 0.76 0.76 0.76 0.67 0.73
# 200 OK
# 0.75 0.7 0.73 0.77 0.74
# 200 OK
# 0.75 0.73 0.76 0.75 0.74
# 200 OK
# 0.79 0.7 0.7 0.69 0.74
# 200 OK
# 0.73 0.75 0.75 0.76 0.77
# 200 OK
# 0.79 0.74 0.72 0.79 0.77
# 200 OK
# 0.75 0.75 0.75 0.74 0.74
# 200 OK
# 0.74 0.77 0.76 0.77 0.75
# 200 OK
# 0.78 0.74 0.76 0.73 0.76
# 200 OK
# 0.78 0.7 0.67 0.75 0.68
# 200 OK
# 0.74 0.74 0.74 0.79 0.77
# 200 OK
# 0.77 0.68 0.74 0.76 0.74
# 200 OK
# 0.77 0.75 0.82 0.76 0.74
# 200 OK
# 0.71 0.78 0.74 0.8 0.72
# 200 OK
# 0.72 0.73 0.74 0.7 0.73
# 200 OK
# 0.77 0.75 0.75 0.71 0.75
# 200 OK
# 0.81 0.66 0.78 0.72 0.66
# 200 OK
# 0.75 0.74 0.78 0.74 0.75
# 200 OK
# 0.77 0.75 0.74 0.74 0.76
# 200 OK
# 0.78 0.67 0.79 0.8 0.78
# 200 OK
# 0.76 0.77 0.78 0.72 0.76
# 200 OK
# 0.79 0.8 0.74 0.79 0.68
# 200 OK
# 0.76 0.74 0.76 0.72 0.73
# 200 OK
# 0.77 0.69 0.74 0.76 0.72
# 200 OK
# 0.73 0.76 0.74 0.72 0.74
# 200 OK
# 0.8 0.75 0.74 0.73 0.75
# 200 OK
# 0.78 0.73 0.78 0.74 0.77
# 200 OK
# 0.77 0.76 0.74 0.73 0.72
# 200 OK
# 0.75 0.75 0.75 0.75 0.77
# 200 OK
# 0.71 0.75 0.75 0.74 0.76
# 200 OK
# 0.76 0.68 0.75 0.76 0.76
# 200 OK
# 0.74 0.76 0.71 0.76 0.75
# 200 OK
# 0.75 0.71 0.78 0.77 0.76
# 200 OK
# 0.75 0.72 0.76 0.77 0.76
# 200 OK
# 0.79 0.71 0.72 0.74 0.74
# 200 OK
# 0.77 0.78 0.79 0.68 0.68
# 200 OK
# 0.77 0.74 0.73 0.74 0.75
# 200 OK
# 0.78 0.72 0.71 0.72 0.78
# 200 OK
# 0.7 0.75 0.72 0.76 0.75
# 200 OK
# 0.77 0.71 0.73 0.78 0.72
# 200 OK
# 0.74 0.81 0.81 0.73 0.78
# 200 OK
# 0.72 0.77 0.79 0.71 0.71
# 200 OK
# 0.72 0.74 0.73 0.76 0.76
# 200 OK
# 0.74 0.67 0.77 0.76 0.73
# 200 OK
# 0.71 0.73 0.7 0.77 0.76
# 200 OK
# 0.73 0.77 0.75 0.75 0.73
# 200 OK
# 0.77 0.75 0.73 0.71 0.76
# 200 OK
# 0.73 0.76 0.77 0.73 0.74
# 200 OK
# 0.77 0.65 0.74 0.75 0.75
# 200 OK
# 0.78 0.73 0.74 0.7 0.76
# 200 OK
# 0.75 0.74 0.74 0.72 0.75
# 200 OK
# 0.75 0.8 0.79 0.73 0.77
# 200 OK
# 0.76 0.76 0.76 0.72 0.73
# 200 OK
# 0.82 0.72 0.8 0.79 0.72
# 200 OK
# 0.74 0.72 0.77 0.77 0.77
# 200 OK
# 0.68 0.74 0.77 0.74 0.73
# 200 OK
# 0.77 0.79 0.78 0.7 0.77
# 200 OK
# 0.76 0.73 0.75 0.71 0.77
# 200 OK
# 0.79 0.73 0.69 0.75 0.76
# 200 OK
# 0.71 0.79 0.77 0.76 0.72
# 200 OK
# 0.74 0.75 0.77 0.78 0.77
# 200 OK
# 0.79 0.75 0.8 0.8 0.83
# 200 OK
# 0.78 0.77 0.73 0.7 0.71
# 200 OK
# 0.72 0.73 0.75 0.79 0.74
# 200 OK
# 0.74 0.76 0.73 0.73 0.74
# 200 OK
# 0.74 0.74 0.76 0.75 0.75
# 200 OK
# 0.74 0.73 0.73 0.7 0.73
# 200 OK
# 0.75 0.76 0.77 0.72 0.73
# 200 OK
# 0.73 0.77 0.74 0.78 0.71
# 200 OK
# 0.75 0.74 0.76 0.77 0.75
# 200 OK
# 0.72 0.76 0.78 0.67 0.74
# 200 OK
# 0.75 0.72 0.75 0.78 0.77
# 200 OK
# 0.76 0.79 0.77 0.7 0.76
# 200 OK
# 0.76 0.74 0.74 0.73 0.76
# 200 OK
# 0.79 0.78 0.76 0.72 0.74
# 200 OK
# 0.77 0.74 0.78 0.73 0.76
# 200 OK
# 0.79 0.77 0.74 0.71 0.77
# 200 OK
# 0.76 0.76 0.77 0.72 0.79
# 200 OK
# 0.77 0.76 0.74 0.74 0.78
# 200 OK
# 0.77 0.73 0.73 0.73 0.74
# 200 OK
# 0.73 0.78 0.75 0.74 0.76
# 200 OK
# 0.72 0.75 0.72 0.77 0.7
# 200 OK
# 0.8 0.69 0.76 0.73 0.73
# 200 OK
# 0.77 0.69 0.67 0.81 0.69
# 200 OK
# 0.75 0.76 0.75 0.72 0.73
# 200 OK
# 0.78 0.68 0.65 0.78 0.73
# 200 OK
# 0.73 0.75 0.74 0.69 0.75
# 200 OK
# 0.7 0.73 0.74 0.79 0.58
# 200 OK
# 0.79 0.75 0.76 0.69 0.77
# 200 OK
# 0.76 0.74 0.75 0.76 0.75
# 200 OK
# 0.78 0.76 0.68 0.76 0.76
# 200 OK
# 0.78 0.7 0.77 0.76 0.78
# 200 OK
# 0.72 0.7 0.75 0.77 0.77
# 200 OK
# 0.75 0.74 0.76 0.73 0.76
# 200 OK
# 0.76 0.77 0.72 0.79 0.76
# 200 OK
# 0.77 0.73 0.73 0.71 0.7
# 200 OK
# 0.75 0.76 0.76 0.75 0.74
# 200 OK
# 0.77 0.72 0.8 0.76 0.75
# 200 OK
# 0.74 0.75 0.74 0.7 0.72
# 200 OK
# 0.73 0.77 0.74 0.76 0.75
# 200 OK
# 0.74 0.77 0.77 0.74 0.73
# 200 OK
# 0.75 0.76 0.78 0.66 0.78
# 200 OK
# 0.72 0.77 0.76 0.73 0.78
# 200 OK
# 0.78 0.73 0.67 0.74 0.74
# 200 OK
# 0.74 0.73 0.78 0.73 0.76
# 200 OK
# 0.75 0.73 0.77 0.75 0.77
# 200 OK
# 0.74 0.74 0.77 0.76 0.74
# 200 OK
# 0.77 0.75 0.75 0.75 0.74
# 200 OK
# 0.76 0.75 0.75 0.73 0.73
# 200 OK
# 0.74 0.75 0.74 0.74 0.74
# 200 OK
# 0.73 0.72 0.68 0.75 0.74
# 200 OK
# 0.72 0.77 0.77 0.73 0.74
# 200 OK
# 0.75 0.66 0.74 0.81 0.8
# 200 OK
# 0.75 0.74 0.75 0.74 0.73
# 200 OK
# 0.73 0.75 0.77 0.75 0.74
# 200 OK
# 0.82 0.72 0.79 0.8 0.75
# 200 OK
# 0.75 0.76 0.77 0.74 0.73
# 200 OK
# 0.8 0.69 0.76 0.75 0.73
# 200 OK
# 0.75 0.7 0.76 0.74 0.74
# 200 OK
# 0.72 0.81 0.79 0.79 0.78
# 200 OK
# 0.76 0.74 0.77 0.76 0.77
# 200 OK
# 0.77 0.69 0.7 0.74 0.73
# 200 OK
# 0.74 0.74 0.69 0.72 0.72
# 200 OK
# 0.78 0.7 0.78 0.74 0.77
# 200 OK
# 0.77 0.77 0.79 0.76 0.8
# 200 OK
# 0.74 0.78 0.79 0.75 0.76
# 200 OK
# 0.82 0.78 0.81 0.68 0.69
# 200 OK
# 0.8 0.72 0.78 0.64 0.76
# 200 OK
# 0.76 0.78 0.79 0.74 0.76
# 200 OK
# 0.61 0.78 0.71 0.77 0.77
# 200 OK
# 0.72 0.74 0.77 0.79 0.77
# 200 OK
# 0.73 0.79 0.77 0.69 0.76
# 200 OK
# 0.74 0.75 0.76 0.75 0.78
# 200 OK
# 0.74 0.76 0.76 0.77 0.77
# 200 OK
# 0.73 0.76 0.77 0.72 0.72
# 200 OK
# 0.75 0.75 0.76 0.76 0.73
# 200 OK
# 0.68 0.73 0.71 0.78 0.77
# 200 OK
# 0.74 0.74 0.79 0.71 0.75
# 200 OK
# 0.74 0.76 0.7 0.68 0.76
# 200 OK
# 0.74 0.74 0.76 0.73 0.7
# 200 OK
# 0.78 0.71 0.75 0.76 0.74
# 200 OK
# 0.67 0.72 0.68 0.77 0.73
# 200 OK
# 0.78 0.78 0.72 0.7 0.77
# 200 OK
# 0.74 0.75 0.76 0.76 0.76
# 200 OK
# 0.76 0.76 0.74 0.73 0.75
# 200 OK
# 0.74 0.77 0.76 0.77 0.74
# 200 OK
# 0.74 0.76 0.75 0.76 0.76
# 200 OK
# 0.81 0.71 0.8 0.74 0.65
# 200 OK
# 0.77 0.74 0.77 0.76 0.74
# 200 OK
# 0.73 0.75 0.74 0.74 0.71
# 200 OK
# 0.78 0.76 0.73 0.71 0.76
# 200 OK
# 0.72 0.76 0.71 0.71 0.75
# 200 OK
# 0.69 0.77 0.71 0.78 0.75
# 200 OK
# 0.75 0.76 0.76 0.78 0.75
# 200 OK
# 0.79 0.7 0.71 0.74 0.73
# 200 OK
# 0.77 0.79 0.65 0.77 0.75
# 200 OK
# 0.75 0.76 0.75 0.75 0.73
# 200 OK
# 0.75 0.77 0.69 0.71 0.75
# 200 OK
# 0.77 0.72 0.73 0.68 0.74
# 200 OK
# 0.74 0.79 0.73 0.73 0.73
# 200 OK
# 0.72 0.77 0.76 0.73 0.75
# 200 OK
# 0.76 0.7 0.63 0.78 0.7
# 200 OK
# 0.78 0.76 0.78 0.7 0.74
# 200 OK
# 0.76 0.78 0.81 0.72 0.77
# 200 OK
# 0.76 0.72 0.77 0.74 0.75
# 200 OK
# 0.76 0.75 0.71 0.74 0.77
# 200 OK
# 0.72 0.77 0.73 0.76 0.74
# 200 OK
# 0.78 0.71 0.72 0.71 0.73
# 200 OK
# 0.78 0.74 0.74 0.7 0.75
# 200 OK
# 0.76 0.79 0.71 0.7 0.76
# 200 OK
# 0.72 0.75 0.7 0.74 0.73
# 200 OK
# 0.73 0.77 0.73 0.73 0.74
# 200 OK
# 0.74 0.76 0.76 0.74 0.73
# 200 OK
# 0.72 0.73 0.79 0.73 0.78
# 200 OK
# 0.75 0.74 0.76 0.75 0.76
# 200 OK
# 0.74 0.76 0.78 0.7 0.73
# 200 OK
# 0.74 0.76 0.73 0.78 0.78
# 200 OK
# 0.72 0.73 0.74 0.73 0.76
# 200 OK
# 0.76 0.73 0.75 0.74 0.69
# 200 OK
# 0.69 0.73 0.75 0.82 0.73
# 200 OK
# 0.74 0.7 0.79 0.79 0.76
# 200 OK
# 0.75 0.73 0.78 0.72 0.75
# 200 OK
# 0.78 0.73 0.72 0.78 0.74
# 200 OK
# 0.75 0.72 0.76 0.75 0.75
# 200 OK
# 0.79 0.77 0.74 0.76 0.71
# 200 OK
# 0.73 0.72 0.75 0.75 0.75
# 200 OK
# 0.74 0.73 0.77 0.78 0.77
# 200 OK
# 0.75 0.74 0.74 0.74 0.77
# 200 OK
# 0.73 0.73 0.75 0.73 0.74
# 200 OK
# 0.75 0.69 0.66 0.77 0.67
# 200 OK
# 0.77 0.77 0.69 0.76 0.73
# 200 OK
# 0.74 0.75 0.74 0.7 0.73
# 200 OK
# 0.78 0.75 0.73 0.67 0.76
# 200 OK
# 0.74 0.76 0.77 0.75 0.74
# 200 OK
# 0.74 0.73 0.69 0.79 0.8
# 200 OK
# 0.73 0.67 0.75 0.78 0.76
# 200 OK
# 0.74 0.73 0.77 0.75 0.72
# 200 OK
# 0.77 0.73 0.73 0.74 0.76
# 200 OK
# 0.75 0.73 0.75 0.78 0.75
# 200 OK
# 0.78 0.72 0.77 0.76 0.73
# 200 OK
# 0.76 0.74 0.68 0.75 0.69
# 200 OK
# 0.77 0.7 0.78 0.71 0.78
# 200 OK
# 0.74 0.74 0.75 0.75 0.74
# 200 OK
# 0.75 0.74 0.78 0.77 0.76
# 200 OK
# 0.76 0.76 0.69 0.76 0.8
# 200 OK
# 0.74 0.75 0.78 0.72 0.77
# 200 OK
# 0.73 0.76 0.76 0.74 0.75
# 200 OK
# 0.83 0.72 0.74 0.71 0.71
# 200 OK
# 0.79 0.69 0.72 0.71 0.78
# 200 OK
# 0.67 0.75 0.73 0.71 0.66
# 200 OK
# 0.74 0.71 0.76 0.7 0.77
# 200 OK
# 0.71 0.73 0.7 0.71 0.73
# 200 OK
# 0.77 0.77 0.76 0.73 0.7
# 200 OK
# 0.75 0.71 0.79 0.76 0.75
# 200 OK
# 0.74 0.73 0.77 0.75 0.67
# 200 OK
# 0.75 0.75 0.74 0.66 0.76
# 200 OK
# 0.74 0.76 0.77 0.77 0.77
# 200 OK
# 0.73 0.79 0.77 0.73 0.73
# 200 OK
# 0.77 0.72 0.76 0.74 0.7
# 200 OK
# 0.74 0.75 0.77 0.73 0.72
# 200 OK
# 0.75 0.76 0.75 0.75 0.75
# 200 OK
# 0.77 0.77 0.74 0.75 0.77
# 200 OK
# 0.72 0.73 0.7 0.71 0.76
# 200 OK
# 0.73 0.77 0.76 0.72 0.75
# 200 OK
# 0.68 0.75 0.77 0.75 0.76
# 200 OK
# 0.75 0.75 0.75 0.72 0.74
# 200 OK
# 0.74 0.76 0.72 0.72 0.76
# 200 OK
# 0.76 0.76 0.77 0.75 0.79
# 200 OK
# 0.8 0.77 0.75 0.74 0.78
# 200 OK
# 0.77 0.77 0.75 0.79 0.73
# 200 OK
# 0.74 0.76 0.67 0.79 0.74
# 200 OK
# 0.77 0.71 0.71 0.72 0.76
# 200 OK
# 0.7 0.73 0.74 0.78 0.76
# 200 OK
# 0.74 0.78 0.75 0.74 0.73
# 200 OK
# 0.8 0.69 0.71 0.77 0.63
# 200 OK
# 0.68 0.77 0.8 0.68 0.75
# 200 OK
# 0.72 0.76 0.74 0.71 0.77
# 200 OK
# 0.73 0.73 0.75 0.72 0.76
# 200 OK
# 0.69 0.77 0.77 0.81 0.79
# 200 OK
# 0.75 0.66 0.76 0.77 0.73
# 200 OK
# 0.75 0.76 0.76 0.74 0.71
# 200 OK
# 0.73 0.75 0.7 0.73 0.68
# 200 OK
# 0.72 0.76 0.71 0.72 0.74
# 200 OK
# 0.77 0.68 0.63 0.73 0.74
# 200 OK
# 0.77 0.74 0.73 0.73 0.75
# 200 OK
# 0.75 0.73 0.77 0.77 0.73
# 200 OK
# 0.8 0.6 0.73 0.74 0.77
# 200 OK
# 0.76 0.73 0.76 0.76 0.78
# 200 OK
# 0.69 0.74 0.72 0.73 0.7
# 200 OK
# 0.79 0.7 0.73 0.78 0.74
# 200 OK
# 0.75 0.72 0.7 0.79 0.69
# 200 OK
# 0.72 0.75 0.78 0.73 0.75
# 200 OK
# 0.76 0.76 0.76 0.75 0.71
# 200 OK
# 0.72 0.75 0.73 0.75 0.74
# 200 OK
# 0.7 0.75 0.75 0.75 0.76
# 200 OK
# 0.83 0.7 0.76 0.72 0.69
# 200 OK
# 0.77 0.8 0.69 0.7 0.77
# 200 OK
# 0.8 0.79 0.73 0.74 0.76
# 200 OK
# 0.77 0.76 0.72 0.69 0.75
# 200 OK
# 0.75 0.77 0.8 0.74 0.73
# 200 OK
# 0.77 0.73 0.75 0.78 0.75
# 200 OK
# 0.74 0.75 0.76 0.74 0.73
# 200 OK
# 0.75 0.76 0.75 0.73 0.76
# 200 OK
# 0.75 0.72 0.73 0.68 0.74
# 200 OK
# 0.75 0.77 0.75 0.74 0.73
# 200 OK
# 0.77 0.76 0.74 0.71 0.76
# 200 OK
# 0.77 0.71 0.71 0.78 0.66
# 200 OK
# 0.77 0.74 0.74 0.75 0.76
# 200 OK
# 0.78 0.67 0.85 0.68 0.69
# 200 OK
# 0.74 0.77 0.81 0.74 0.78
# 200 OK
# 0.73 0.75 0.68 0.7 0.74
# 200 OK
# 0.8 0.72 0.66 0.75 0.7
# 200 OK
# 0.74 0.73 0.76 0.74 0.74
# 200 OK
# 0.74 0.78 0.76 0.73 0.74
# 200 OK
# 0.74 0.72 0.8 0.79 0.67
# 200 OK
# 0.78 0.76 0.76 0.75 0.69
# 200 OK
# 0.71 0.75 0.76 0.74 0.73
# 200 OK
# 0.76 0.74 0.76 0.74 0.78
# 200 OK
# 0.76 0.65 0.76 0.78 0.73
# 200 OK
# 0.74 0.73 0.71 0.72 0.77
# 200 OK
# 0.8 0.78 0.75 0.78 0.65
# 200 OK
# 0.75 0.77 0.72 0.75 0.78
# 200 OK
# 0.75 0.74 0.74 0.75 0.73
# 200 OK
# 0.78 0.68 0.72 0.75 0.62
# 200 OK
# 0.77 0.73 0.79 0.76 0.75
# 200 OK
# 0.69 0.75 0.69 0.71 0.69
# 200 OK
# 0.74 0.76 0.75 0.77 0.79
# 200 OK
# 0.75 0.7 0.72 0.76 0.72
# 200 OK
# 0.81 0.73 0.74 0.67 0.77
# 200 OK
# 0.78 0.75 0.75 0.73 0.75
# 200 OK
# 0.73 0.73 0.75 0.75 0.72
# 200 OK
# 0.73 0.73 0.75 0.78 0.75
# 200 OK
# 0.74 0.78 0.74 0.76 0.7
# 200 OK
# 0.74 0.75 0.74 0.77 0.73
# 200 OK
# 0.68 0.75 0.68 0.77 0.72
# 200 OK
# 0.74 0.78 0.8 0.75 0.74
# 200 OK
# 0.73 0.74 0.75 0.76 0.74
# 200 OK
# 0.75 0.75 0.69 0.75 0.72
# 200 OK
# 0.74 0.75 0.78 0.71 0.75
# 200 OK
# 0.73 0.75 0.79 0.74 0.72
# 200 OK
# 0.73 0.72 0.75 0.77 0.72
# 200 OK
# 0.8 0.68 0.72 0.78 0.72
# 200 OK
# 0.72 0.75 0.77 0.77 0.77
# 200 OK
# 0.74 0.75 0.73 0.69 0.74
# 200 OK
# 0.71 0.8 0.79 0.7 0.77
# 200 OK
# 0.74 0.77 0.77 0.65 0.79
# 200 OK
# 0.75 0.78 0.75 0.74 0.76
# 200 OK
# 0.78 0.68 0.68 0.74 0.78
# 200 OK
# 0.77 0.71 0.74 0.72 0.71
# 200 OK
# 0.73 0.71 0.75 0.72 0.76
# 200 OK
# 0.75 0.77 0.74 0.73 0.75
# 200 OK
# 0.72 0.71 0.77 0.78 0.76
# 200 OK
# 0.77 0.78 0.69 0.76 0.78
# 200 OK
# 0.69 0.76 0.8 0.74 0.78
# 200 OK
# 0.76 0.76 0.77 0.76 0.72
# 200 OK
# 0.72 0.72 0.77 0.73 0.74
# 200 OK
# 0.76 0.75 0.74 0.77 0.73
# 200 OK
# 0.73 0.8 0.69 0.72 0.63
# 200 OK
# 0.74 0.74 0.77 0.69 0.75
# 200 OK
# 0.75 0.74 0.76 0.75 0.78
# 200 OK
# 0.79 0.73 0.7 0.77 0.77
# 200 OK
# 0.77 0.72 0.78 0.77 0.75
# 200 OK
# 0.76 0.75 0.74 0.74 0.75
# 200 OK
# 0.78 0.73 0.68 0.76 0.66
# 200 OK
# 0.75 0.8 0.8 0.7 0.77
# 200 OK
# 0.77 0.76 0.79 0.77 0.74
# 200 OK
# 0.77 0.71 0.8 0.78 0.74
# 200 OK
# 0.74 0.78 0.73 0.76 0.7
# 200 OK
# 0.75 0.78 0.74 0.76 0.73
# 200 OK
# 0.75 0.74 0.75 0.71 0.74
# 200 OK
# 0.75 0.75 0.71 0.68 0.76
# 200 OK
# 0.76 0.74 0.72 0.74 0.76
# 200 OK
# 0.73 0.75 0.79 0.78 0.75
# 200 OK
# 0.8 0.67 0.77 0.8 0.74
# 200 OK
# 0.76 0.73 0.74 0.75 0.76
# 200 OK
# 0.73 0.77 0.77 0.77 0.74
# 200 OK
# 0.72 0.75 0.74 0.72 0.72
# 200 OK
# 0.75 0.73 0.7 0.73 0.72
# 200 OK
# 0.81 0.62 0.79 0.72 0.73
# 200 OK
# 0.75 0.76 0.74 0.74 0.76
# 200 OK
# 0.75 0.74 0.73 0.78 0.73
# 200 OK
# 0.75 0.73 0.75 0.73 0.73
# 200 OK
# 0.77 0.67 0.71 0.77 0.8
# 200 OK
# 0.76 0.71 0.69 0.73 0.74
# 200 OK
# 0.78 0.73 0.76 0.72 0.75
# 200 OK
# 0.75 0.7 0.75 0.76 0.77
# 200 OK
# 0.77 0.75 0.74 0.74 0.73
# 200 OK
# 0.74 0.75 0.69 0.73 0.76
# 200 OK
# 0.73 0.74 0.72 0.68 0.75
# 200 OK
# 0.74 0.75 0.76 0.76 0.7
# 200 OK
# 0.72 0.76 0.78 0.71 0.75
# 200 OK
# 0.74 0.74 0.75 0.77 0.74
# 200 OK
# 0.66 0.79 0.7 0.77 0.7
# 200 OK
# 0.75 0.71 0.78 0.76 0.76
# 200 OK
# 0.8 0.76 0.74 0.73 0.72
# 200 OK
# 0.71 0.73 0.78 0.68 0.76
# 200 OK
# 0.74 0.75 0.75 0.77 0.74
# 200 OK
# 0.72 0.73 0.76 0.78 0.75
# 200 OK
# 0.76 0.72 0.76 0.75 0.77
# 200 OK
# 0.73 0.74 0.77 0.74 0.74
# 200 OK
# 0.76 0.75 0.72 0.77 0.72
# 200 OK
# 0.75 0.74 0.76 0.78 0.75
# 200 OK
# 0.76 0.74 0.79 0.74 0.76
# 200 OK
# 0.78 0.76 0.75 0.74 0.75
# 200 OK
# 0.75 0.75 0.71 0.69 0.73
# 200 OK
# 0.75 0.67 0.75 0.78 0.73
# 200 OK
# 0.73 0.75 0.76 0.71 0.72
# 200 OK
# 0.74 0.73 0.79 0.73 0.74
# 200 OK
# 0.78 0.69 0.76 0.74 0.73
# 200 OK
# 0.77 0.78 0.77 0.75 0.8
# 200 OK
# 0.78 0.72 0.74 0.79 0.77
# 200 OK
# 0.76 0.71 0.66 0.73 0.74
# 200 OK
# 0.77 0.72 0.66 0.73 0.72
# 200 OK
# 0.73 0.72 0.76 0.73 0.77
# 200 OK
# 0.74 0.72 0.76 0.77 0.73
# 200 OK
# 0.74 0.72 0.73 0.73 0.74
# 200 OK
# 0.74 0.78 0.73 0.77 0.74
# 200 OK
# 0.74 0.74 0.8 0.76 0.73
# 200 OK
# 0.74 0.77 0.77 0.68 0.75
# 200 OK
# 0.75 0.73 0.72 0.74 0.76
# 200 OK
# 0.74 0.75 0.76 0.75 0.74
# 200 OK
# 0.68 0.73 0.73 0.76 0.7
# 200 OK
# 0.79 0.63 0.76 0.69 0.8
# 200 OK
# 0.72 0.81 0.8 0.75 0.76
# 200 OK
# 0.79 0.73 0.77 0.73 0.76
# 200 OK
# 0.76 0.8 0.78 0.75 0.79
# 200 OK
# 0.78 0.69 0.78 0.77 0.77
# 200 OK
# 0.74 0.73 0.74 0.73 0.78
# 200 OK
# 0.72 0.75 0.78 0.74 0.74
# 200 OK
# 0.73 0.75 0.73 0.7 0.74
# 200 OK
# 0.8 0.76 0.75 0.76 0.69
# 200 OK
# 0.74 0.74 0.73 0.71 0.71
# 200 OK
# 0.75 0.73 0.78 0.72 0.73
# 200 OK
# 0.74 0.76 0.75 0.78 0.73
# 200 OK
# 0.71 0.71 0.75 0.72 0.76
# 200 OK
# 0.75 0.76 0.72 0.72 0.73
# 200 OK
# 0.75 0.73 0.76 0.75 0.74
# 200 OK
# 0.77 0.65 0.73 0.77 0.75
# 200 OK
# 0.76 0.75 0.76 0.75 0.7
# 200 OK
# 0.72 0.74 0.76 0.79 0.77
# 200 OK
# 0.65 0.78 0.69 0.76 0.77
# 200 OK
# 0.74 0.75 0.74 0.77 0.77
# 200 OK
# 0.73 0.74 0.76 0.78 0.76
# 200 OK
# 0.73 0.72 0.75 0.75 0.75
# 200 OK
# 0.75 0.76 0.77 0.71 0.76
# 200 OK
# 0.77 0.66 0.69 0.74 0.75
# 200 OK
# 0.74 0.75 0.72 0.71 0.73
# 200 OK
# 0.83 0.75 0.8 0.73 0.65
# 200 OK
# 0.68 0.73 0.75 0.71 0.78
# 200 OK
# 0.73 0.75 0.75 0.77 0.72
# 200 OK
# 0.73 0.74 0.82 0.78 0.73
# 200 OK
# 0.75 0.79 0.77 0.72 0.76
# 200 OK
# 0.75 0.77 0.72 0.79 0.77
# 200 OK
# 0.75 0.77 0.76 0.8 0.75
# 200 OK
# 0.7 0.71 0.76 0.73 0.74
# 200 OK
# 0.74 0.72 0.77 0.75 0.73
# 200 OK
# 0.76 0.75 0.75 0.76 0.72
# 200 OK
# 0.76 0.73 0.77 0.74 0.73
# 200 OK
# 0.74 0.79 0.75 0.73 0.68
# 200 OK
# 0.75 0.77 0.7 0.73 0.76
# 200 OK
# 0.77 0.73 0.75 0.77 0.77
# 200 OK
# 0.76 0.74 0.78 0.76 0.77
# 200 OK
# 0.68 0.79 0.73 0.77 0.7
# 200 OK
# 0.77 0.73 0.72 0.71 0.74
# 200 OK
# 0.77 0.76 0.63 0.76 0.77
# 200 OK
# 0.7 0.81 0.74 0.66 0.68
# 200 OK
# 0.74 0.78 0.78 0.74 0.75
# 200 OK
# 0.77 0.7 0.72 0.79 0.77
# 200 OK
# 0.75 0.75 0.77 0.73 0.75
# 200 OK
# 0.79 0.7 0.78 0.75 0.74
# 200 OK
# 0.7 0.74 0.68 0.81 0.8
# 200 OK
# 0.76 0.61 0.75 0.8 0.69
# 200 OK
# 0.75 0.76 0.77 0.76 0.74
# 200 OK
# 0.76 0.69 0.77 0.76 0.73
# 200 OK
# 0.73 0.73 0.76 0.71 0.75
# 200 OK
# 0.77 0.74 0.7 0.73 0.72
# 200 OK
# 0.77 0.69 0.74 0.75 0.72
# 200 OK
# 0.71 0.75 0.75 0.77 0.75
# 200 OK
# 0.77 0.73 0.75 0.7 0.77
# 200 OK
# 0.74 0.77 0.75 0.78 0.71
# 200 OK
# 0.73 0.77 0.77 0.76 0.76
# 200 OK
# 0.74 0.73 0.8 0.78 0.66
# 200 OK
# 0.75 0.76 0.7 0.73 0.75
# 200 OK
# 0.75 0.66 0.79 0.79 0.74
# 200 OK
# 0.83 0.74 0.79 0.76 0.66
# 200 OK
# 0.74 0.72 0.78 0.74 0.75
# 200 OK
# 0.77 0.73 0.72 0.72 0.74
# 200 OK
# 0.69 0.76 0.73 0.76 0.76
# 200 OK
# 0.78 0.74 0.77 0.68 0.78
# 200 OK
# 0.74 0.78 0.77 0.75 0.74
# 200 OK
# 0.75 0.77 0.78 0.69 0.74
# 200 OK
# 0.74 0.75 0.67 0.68 0.75
# 200 OK
# 0.75 0.7 0.74 0.74 0.77
# 200 OK
# 0.75 0.75 0.74 0.77 0.77
# 200 OK
# 0.79 0.73 0.79 0.8 0.79
# 200 OK
# 0.79 0.7 0.76 0.67 0.77
# 200 OK
# 0.78 0.75 0.78 0.77 0.74
# 200 OK
# 0.77 0.72 0.75 0.75 0.74
# 200 OK
# 0.79 0.7 0.73 0.73 0.73
# 200 OK
# 0.76 0.76 0.76 0.74 0.77
# 200 OK
# 0.74 0.75 0.75 0.78 0.74
# 200 OK
# 0.75 0.68 0.76 0.76 0.73
# 200 OK
# 0.72 0.69 0.77 0.77 0.78
# 200 OK
# 0.73 0.73 0.76 0.74 0.75
# 200 OK
# 0.76 0.74 0.76 0.78 0.73

# %% [markdown]
# ### Пример передачи в виде post запросов содержимого pd.DataFrame

# %%
# Загружаем тестовую выборку
df = pd.read_csv(
    filepath_or_buffer='./data/model_val.csv',
    sep=';',
    index_col='SkillFactory_Id')
banks = ['BankA_decision',
             'BankB_decision',
             'BankC_decision',
             'BankD_decision',
             'BankE_decision']
df = df.drop(banks, axis='columns')
df = df.dropna(how='all')
df.rename(columns={
    "employment status": "employment_status",
    "Family status": "Family_status"}, 
    inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1251 entries, 2443.0 to 768.0
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BirthDate          1251 non-null   object
#  1   education          1251 non-null   object
#  2   employment_status  1251 non-null   object
#  3   Value              1251 non-null   object
#  4   JobStartDate       1251 non-null   object
#  5   Position           1251 non-null   object
#  6   MonthProfit        1251 non-null   float64
#  7   MonthExpense       1251 non-null   float64
#  8   Gender             1251 non-null   float64
#  9   Family_status      1251 non-null   object
#  10  ChildCount         1251 non-null   float64
#  11  SNILS              1251 non-null   float64
#  12  Merch_code         1251 non-null   float64
#  13  Loan_amount        1251 non-null   float64
#  14  Loan_term          1251 non-null   float64
#  15  Goods_category     1251 non-null   object
# dtypes: float64(8), object(8)
# memory usage: 166.1+ KB

# %%
# Отправляем произвольные 50 строк из загруженного датафрейма
frame_for_send = df.sample(50).to_dict('records')
for i in range(len(frame_for_send)):
    #json_data = json.dumps(frame_for_send[i]).encode('utf8')
    json_data = df.iloc[i].to_json().encode('utf8')
    r = requests.post(
        # Запрос на сервер, который поднят на нашей виртуальной машине в Яндекс Облаке
        'http://158.160.135.101:5000/AskOraqul/', data=json_data)
        # Запрос на локальный сервер (в случае развертывания на локальной машине)
        #'http://127.0.0.1:5000/AskOraqul/', data=json_data)
    print(r.status_code, r.reason)
    resp = r.content.decode()[1:-1].split(',')
    BankA_decision = round(float(resp[0]), 2)
    BankB_decision = round(float(resp[1]), 2)
    BankC_decision = round(float(resp[2]), 2)
    BankD_decision = round(float(resp[3]), 2)
    BankE_decision = round(float(resp[4]), 2)
    print(BankA_decision, BankB_decision, BankC_decision, BankD_decision, BankE_decision)
# Out:
# 200 OK
# 0.76 0.78 0.71 0.78 0.77
# 200 OK
# 0.72 0.73 0.75 0.76 0.73
# 200 OK
# 0.74 0.73 0.76 0.72 0.73
# 200 OK
# 0.81 0.79 0.8 0.79 0.74
# 200 OK
# 0.73 0.74 0.71 0.69 0.73
# 200 OK
# 0.73 0.77 0.78 0.76 0.73
# 200 OK
# 0.73 0.72 0.7 0.77 0.73
# 200 OK
# 0.76 0.66 0.76 0.79 0.75
# 200 OK
# 0.76 0.73 0.75 0.73 0.76
# 200 OK
# 0.79 0.78 0.7 0.72 0.75
# 200 OK
# 0.77 0.7 0.69 0.75 0.78
# 200 OK
# 0.79 0.74 0.75 0.75 0.73
# 200 OK
# 0.75 0.78 0.73 0.76 0.76
# 200 OK
# 0.75 0.74 0.68 0.74 0.73
# 200 OK
# 0.78 0.71 0.74 0.76 0.77
# 200 OK
# 0.75 0.76 0.75 0.69 0.72
# 200 OK
# 0.72 0.76 0.75 0.74 0.76
# 200 OK
# 0.74 0.8 0.75 0.68 0.74
# 200 OK
# 0.65 0.77 0.72 0.77 0.77
# 200 OK
# 0.74 0.77 0.77 0.77 0.76
# 200 OK
# 0.75 0.74 0.76 0.76 0.74
# 200 OK
# 0.77 0.71 0.74 0.74 0.72
# 200 OK
# 0.76 0.77 0.74 0.7 0.75
# 200 OK
# 0.77 0.74 0.78 0.68 0.73
# 200 OK
# 0.76 0.75 0.74 0.76 0.72
# 200 OK
# 0.78 0.68 0.65 0.71 0.74
# 200 OK
# 0.76 0.77 0.71 0.73 0.76
# 200 OK
# 0.76 0.77 0.73 0.79 0.75
# 200 OK
# 0.72 0.75 0.74 0.76 0.74
# 200 OK
# 0.79 0.78 0.79 0.76 0.76
# 200 OK
# 0.73 0.77 0.74 0.79 0.83
# 200 OK
# 0.76 0.76 0.76 0.76 0.71
# 200 OK
# 0.77 0.78 0.74 0.76 0.73
# 200 OK
# 0.72 0.78 0.69 0.71 0.73
# 200 OK
# 0.79 0.68 0.81 0.77 0.8
# 200 OK
# 0.74 0.77 0.78 0.77 0.72
# 200 OK
# 0.76 0.72 0.71 0.81 0.75
# 200 OK
# 0.74 0.74 0.77 0.81 0.76
# 200 OK
# 0.7 0.78 0.73 0.76 0.73
# 200 OK
# 0.79 0.71 0.71 0.75 0.66
# 200 OK
# 0.8 0.73 0.75 0.72 0.71
# 200 OK
# 0.79 0.73 0.75 0.71 0.77
# 200 OK
# 0.77 0.74 0.75 0.79 0.73
# 200 OK
# 0.73 0.75 0.76 0.75 0.72
# 200 OK
# 0.73 0.76 0.68 0.72 0.75
# 200 OK
# 0.74 0.73 0.77 0.76 0.77
# 200 OK
# 0.73 0.77 0.72 0.72 0.84
# 200 OK
# 0.72 0.74 0.69 0.72 0.76
# 200 OK
# 0.76 0.72 0.76 0.8 0.75
# 200 OK
# 0.75 0.75 0.73 0.73 0.68
